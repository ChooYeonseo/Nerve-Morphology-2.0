# %% [markdown]
# # Manually Setting the Nerve Morphology
#
# Due to high variations by nerve, it is best to set the morphology manually.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

from nmutilis.readcsv import helper_dict, raw_dict
from nmutilis.bone_model import Bone
from nmutilis.NerveNodule import Nerve, Node
# Out:
# {'22-20L': {'brch1_x': 4.715682122,
#             'brch1_y': 8.625734827,
#             'brchA2_x': nan,
#             'brchA2_y': nan,
#             'brchP2_x': nan,
#             'brchP2_y': nan,
#             'sp_x': nan,
#             'sp_y': nan,
#             'tip_cp_recal': 10.0714286},
#  '22-20R': {'brch1_x': 3.766570308,
#             'brch1_y': 8.188034272,
#             'brchA2_x': 1.69928603,
#             'brchA2_y': 1.188801061,
#             'brchP2_x': nan,
#             'brchP2_y': nan,
#             'sp_x': 1.966382,
#             'sp_y': 1.19733636,
#             'tip_cp_recal': 10.6913457},
#  '23-21L': {'brch1_x': 3.384606282,
#             'brch1_y': 7.059121038,
#             'brchA2_x': nan,
#             'brchA2_y': nan,
#             'brchP2_x': nan,
#             'brchP2_y': nan,
#             'sp_x': nan,
#             'sp_y': nan,
#             'tip_cp_recal': 19.5307654},
#  '23-21R': {'brch1_x': 0.20342862,
#             'brch1_y': 0.090092941,
# ...

# %%
code_list = list(raw_dict.keys())
scale = 1 * 36.9 / 5
a = Bone(scale, 2000)
code_list
# Out:
# ['23-21R',
#  '23-21L',
#  '23-27R',
#  '23-27L',
#  '23-34R',
#  '23-34L',
#  '22-20R',
#  '22-20L',
#  '23-6R',
#  '23-6L',
#  '23-24R',
#  '23-24L',
#  '23-25R',
#  '23-25L',
#  '24-10R',
#  '24-10L',
#  '23-49R',
#  '23-49L']

# %%
Nerve_list = []

# %% [markdown]
# # 23-21R Morphology

# %% [markdown]
# ## Step1: Create Nerve Class
#
# From the code list, assign a code. Then access the data

# %%
code = code_list[0]
N23_21R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 8 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-25.275977337110483, -18.45)
# tip_sn2's coordinate: (-19.21308781869689, -18.45)
# mid_sn1's coordinate: (-5.4356940509915015, 0.0)
# mid_sn2's coordinate: (-0.0, 0.0)
# mid10_sn1's coordinate: (19.056921690306908, 100.64710355177588)
# mid12_sn1's coordinate: (27.573633729045824, 122.392076038019)
# tip_cp's coordinate: (32.37274208794737, 137.924199342)
# brch1's coordinate: (1.5013032156, 0.66488590458)

# %% [markdown]
# ## Step 2: Add relations manually

# %%
N23_21R.add_relation('tip_cp', 'mid12_sn1')
N23_21R.add_relation('mid12_sn1', 'mid10_sn1')
N23_21R.add_relation('mid10_sn1', 'brch1')
N23_21R.add_relation('brch1', 'mid_sn1')
N23_21R.add_relation('brch1', 'mid_sn2')
N23_21R.add_relation('mid_sn1', 'tip_sn1')
N23_21R.add_relation('mid_sn2', 'tip_sn2')

# %%
lines = N23_21R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_21R)

# %% [markdown]
# # 23-21L Morphology

# %%
code = code_list[1]
N23_21L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 8 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (1.8035393258426975, -18.45)
# tip_sn2's coordinate: (0.9743258426966293, -18.45)
# mid_sn1's coordinate: (13.992977528089886, 0.0)
# mid_sn2's coordinate: (16.169662921348312, 0.0)
# mid10_sn1's coordinate: (25.172664759345967, 100.64710355177588)
# mid12_sn1's coordinate: (28.025237956056678, 122.392076038019)
# tip_cp's coordinate: (32.536238122421054, 144.137048652)
# brch1's coordinate: (24.97839436116, 52.09631326044)

# %%
N23_21L.add_relation('tip_cp', 'mid12_sn1')
N23_21L.add_relation('mid12_sn1', 'mid10_sn1')
N23_21L.add_relation('mid10_sn1', 'brch1')
N23_21L.add_relation('brch1', 'mid_sn1')
N23_21L.add_relation('brch1', 'mid_sn2')
N23_21L.add_relation('mid_sn1', 'tip_sn1')
N23_21L.add_relation('mid_sn2', 'tip_sn2')

lines = N23_21L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_21L)

# %% [markdown]
# # 23-27R Morphology

# %%
code = code_list[2]
N23_27R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 14 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-3.894999999999998, -18.45)
# tip_sn2's coordinate: (2.460000000000001, -18.45)
# tip_sn3's coordinate: (9.84, -18.45)
# mid_sn1's coordinate: (4.1, 0.0)
# mid_sn2's coordinate: (10.66, 0.0)
# mid_sn3's coordinate: (16.9125, 0.0)
# mid_sn4's coordinate: (23.6775, 0.0)
# mid10_sn1's coordinate: (30.16176588294147, 100.64710355177588)
# mid12_sn1's coordinate: (32.9890020010005, 122.392076038019)
# tip_cp's coordinate: (31.69294278773684, 112.091825934)
# brch1's coordinate: (27.87548472576, 83.467150191)
# brchA2's coordinate: (17.32664125584, 13.94429578812)
# brchP2's coordinate: (25.362338875920003, 30.9213531081)
# sp's coordinate: (32.14279046556, 0.0)

# %%
N23_27R.add_relation('mid12_sn1','tip_cp')
N23_27R.add_relation('tip_cp', 'mid10_sn1')
N23_27R.add_relation('mid10_sn1', 'brch1')
N23_27R.add_relation('brch1', 'brchA2')
N23_27R.add_relation('brch1', 'brchP2')
N23_27R.add_relation('brchA2', 'mid_sn1')
N23_27R.add_relation('brchA2', 'mid_sn2')
N23_27R.add_relation('brchP2', 'mid_sn3')
N23_27R.add_relation('brchP2', 'mid_sn4')

N23_27R.add_relation('mid_sn2', 'tip_sn1')
N23_27R.add_relation('mid_sn3', 'tip_sn2')
N23_27R.add_relation('mid_sn4', 'tip_sn3')

lines = N23_27R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_27R)

# %%
export_file_name = "./branches/" + code + "_branches.npz"
print(export_file_name)
N23_27R.save_branch(export_file_name)
# Out:
# ./branches/23-27R_branches.npz

# %% [markdown]
# # 23-27L Morphology

# %%
code = code_list[3]
N23_27L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 14 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-4.597377049180325, -18.45)
# tip_sn2's coordinate: (-0.7662295081967212, -18.45)
# mid_sn1's coordinate: (6.95655737704918, 0.0)
# mid_sn2's coordinate: (10.182786885245902, 0.0)
# mid_sn3's coordinate: (20.163934426229506, 0.0)
# mid_sn4's coordinate: (20.365573770491803, 0.0)
# mid10_sn1's coordinate: (25.846683915728356, 100.64710355177588)
# mid10_sn2's coordinate: (27.963897030482453, 100.64710355177588)
# mid12_sn1's coordinate: (28.93941183706607, 122.392076038019)
# mid12_sn2's coordinate: (30.754165935426727, 122.392076038019)
# tip_cp's coordinate: (32.72447368421052, 151.29)
# brch1's coordinate: (27.3188755539, 138.76776027900002)
# brchA2's coordinate: (21.64298083002, 37.324193580899994)
# brchP2's coordinate: (34.90772114808, 29.27288322396)

# %%
N23_27L.add_relation('tip_cp', 'brch1')
N23_27L.add_relation('brch1', 'mid12_sn1')
N23_27L.add_relation('brch1', 'mid12_sn2')
N23_27L.add_relation('mid12_sn1', 'mid10_sn1')
N23_27L.add_relation('mid12_sn2', 'mid10_sn2')
N23_27L.add_relation('mid10_sn1', 'brchA2')
N23_27L.add_relation('mid10_sn2', 'brchP2')

N23_27L.add_relation('brchA2', 'mid_sn1')
N23_27L.add_relation('brchA2', 'mid_sn2')
N23_27L.add_relation('mid_sn1', 'tip_sn1')
N23_27L.add_relation('mid_sn2', 'tip_sn2')
N23_27L.add_relation('brchP2', 'mid_sn3')
N23_27L.add_relation('brchP2', 'mid_sn4')


lines = N23_27L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_27L)

# %%
export_file_name = "./branches/" + code + "_branches.npz"
print(export_file_name)
N23_27L.save_branch(export_file_name)
# Out:
# ./branches/23-27L_branches.npz

# %% [markdown]
# # 23-34R Morphology

# %%
code = code_list[4]
N23_34R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 8 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-5.304986737400528, -18.45)
# tip_sn2's coordinate: (-0.8025994694960215, -18.45)
# mid_sn1's coordinate: (1.859681697612732, 0.0)
# mid_sn2's coordinate: (6.8514588859416445, 0.0)
# mid10_sn1's coordinate: (28.944816280819456, 100.64710355177588)
# mid12_sn1's coordinate: (29.02766247845408, 122.392076038019)
# tip_cp's coordinate: (32.835451133368416, 155.507143068)
# brch1's coordinate: (23.33398640688, 42.02235025938)

# %%
N23_34R.add_relation('tip_cp', 'mid12_sn1')
N23_34R.add_relation('mid12_sn1', 'mid10_sn1')
N23_34R.add_relation('mid10_sn1', 'brch1')
N23_34R.add_relation('brch1', 'mid_sn1')
N23_34R.add_relation('brch1', 'mid_sn2')
N23_34R.add_relation('mid_sn1', 'tip_sn1')
N23_34R.add_relation('mid_sn2', 'tip_sn2')

lines = N23_34R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_34R)

# %% [markdown]
# # 23-34L Morphology

# %%
code = code_list[5]
N23_34L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 8 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-18.182608695652178, -18.45)
# tip_sn2's coordinate: (-7.914782608695651, -18.45)
# mid_sn1's coordinate: (1.0695652173913044, 0.0)
# mid_sn2's coordinate: (5.240869565217391, 0.0)
# mid10_sn1's coordinate: (31.39176588294147, 100.64710355177588)
# mid12_sn1's coordinate: (33.996175914043974, 122.392076038019)
# tip_cp's coordinate: (31.391765881105268, 100.64710348199999)
# brch1's coordinate: (27.02663867556, 58.15165982814)

# %%
N23_34L.add_relation('mid12_sn1', 'tip_cp')
N23_34L.add_relation('mid10_sn1', 'brch1')
N23_34L.add_relation('brch1', 'mid_sn1')
N23_34L.add_relation('brch1', 'mid_sn2')
N23_34L.add_relation('mid_sn1', 'tip_sn1')
N23_34L.add_relation('mid_sn2', 'tip_sn2')

lines = N23_34L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_34L)

# %% [markdown]
# # 22-20R Morphology

# %%
code = code_list[6]
N22_20R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 10 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-5.933918918918918, -18.45)
# tip_sn2's coordinate: (5.618108108108109, -18.45)
# mid_sn1's coordinate: (3.241216216216216, 0.0)
# mid_sn2's coordinate: (14.294594594594594, 0.0)
# mid10_sn1's coordinate: (35.297846964022554, 100.64710355177588)
# mid12_sn1's coordinate: (35.87008308208158, 122.392076038019)
# tip_cp's coordinate: (30.819529770157892, 78.902131266)
# brch1's coordinate: (27.79728887304, 60.42769292735999)
# brchA2's coordinate: (12.5407309014, 8.77335183018)
# sp's coordinate: (14.51189916, 8.8363423368)

# %%
N22_20R.add_relation('mid12_sn1', 'mid10_sn1')
N22_20R.add_relation('mid10_sn1', 'tip_cp')
N22_20R.add_relation('tip_cp', 'brch1')
N22_20R.add_relation('brch1', 'brchA2')
N22_20R.add_relation('brch1', 'sp')
N22_20R.add_relation('brchA2', 'mid_sn1')
N22_20R.add_relation('brchA2', 'mid_sn2')
N22_20R.add_relation('mid_sn1', 'tip_sn1')
N22_20R.add_relation('mid_sn2', 'tip_sn2')


lines = N22_20R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N22_20R)

# %% [markdown]
# # 22-20L Morphology

# %%
code = code_list[7]
N22_20L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 8 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-1.5814285714285727, -18.45)
# tip_sn2's coordinate: (5.886428571428571, -18.45)
# mid_sn1's coordinate: (12.387857142857142, 0.0)
# mid_sn2's coordinate: (17.659285714285716, 0.0)
# mid10_sn1's coordinate: (35.9603373115129, 100.64710355177588)
# mid12_sn1's coordinate: (39.25614485814336, 122.392076038019)
# tip_cp's coordinate: (30.699135343894735, 74.327143068)
# brch1's coordinate: (34.80173406036, 63.657923023260004)

# %%
N22_20L.add_relation('mid12_sn1', 'mid10_sn1')
N22_20L.add_relation('mid10_sn1', 'tip_cp')
N22_20L.add_relation('tip_cp', 'brch1')
N22_20L.add_relation('brch1', 'mid_sn1')
N22_20L.add_relation('brch1', 'mid_sn2')
N22_20L.add_relation('mid_sn1', 'tip_sn1')
N22_20L.add_relation('mid_sn2', 'tip_sn2')

lines = N22_20L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N22_20L)

# %% [markdown]
# # 23-6R Morphology

# %%
code = code_list[8]
N23_6R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 5 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (8.770994764397905, -18.45)
# mid_sn1's coordinate: (19.222774869109944, 0.0)
# mid10_sn1's coordinate: (29.170038134250373, 100.64710355177588)
# mid12_sn1's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (31.96400199205263, 122.39207569799999)

# %%
N23_6R.add_relation('mid12_sn1', 'mid10_sn1')
N23_6R.add_relation('mid10_sn1', 'mid_sn1')
N23_6R.add_relation('mid_sn1', 'tip_sn1')

lines = N23_6R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_6R)

# %% [markdown]
# # 23-6L Morphology

# %%
code = code_list[9]
N23_6L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 5 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (6.6762371134020615, -18.45)
# mid_sn1's coordinate: (11.79278350515464, 0.0)
# mid10_sn1's coordinate: (28.348466913869306, 100.64710355177588)
# mid12_sn1's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (31.96400199205263, 122.39207569799999)

# %%
N23_6L.add_relation('mid12_sn1', 'mid10_sn1')
N23_6L.add_relation('mid10_sn1', 'mid_sn1')
N23_6L.add_relation('mid_sn1', 'tip_sn1')

lines = N23_6L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1])
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_6L)

# %% [markdown]
# # 23-24R Morphology

# %%
code = code_list[10]
N23_24R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 7 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-12.914999999999997, -18.45)
# mid_sn1's coordinate: (-4.4971875, 0.0)
# mid_sn2's coordinate: (1.7296874999999998, 0.0)
# mid10_sn1's coordinate: (25.62614088294147, 100.64710355177588)
# mid12_sn1's coordinate: (25.7371270010005, 122.392076038019)
# tip_cp's coordinate: (30.53276883880579, 68.00521587461999)
# brch1's coordinate: (29.427407568, 59.5247103558)

# %%
N23_24R.add_relation('mid12_sn1', 'mid10_sn1')
N23_24R.add_relation('mid10_sn1', 'tip_cp')
N23_24R.add_relation('tip_cp', 'brch1')
N23_24R.add_relation('brch1', 'mid_sn1')
N23_24R.add_relation('brch1', 'mid_sn2')
N23_24R.add_relation('mid_sn1', 'tip_sn1')



lines = N23_24R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_24R)

# %% [markdown]
# # 23-24L Morphology

# %%
code = code_list[11]
N23_24L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 6 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-2.2140000000000004, -18.45)
# mid_sn1's coordinate: (-8.539714285714286, 0.0)
# mid_sn2's coordinate: (-0.0, 0.0)
# mid10_sn1's coordinate: (28.22890874008433, 100.64710355177588)
# mid12_sn1's coordinate: (29.012002001000496, 122.392076038019)
# tip_cp's coordinate: (32.69672933163157, 150.235714602)

# %%
N23_24L.add_relation('tip_cp', 'mid12_sn1')
N23_24L.add_relation('mid12_sn1', 'mid10_sn1')
N23_24L.add_relation('mid10_sn1', 'mid_sn1')
N23_24L.add_relation('mid10_sn1', 'mid_sn2')
N23_24L.add_relation('mid_sn2', 'tip_sn1')



lines = N23_24L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_24L)

# %% [markdown]
# # 23-25R Morphology

# %%
code = code_list[12]
N23_25R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 7 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (2.004444444444445, -18.45)
# tip_sn2's coordinate: (11.115555555555556, -18.45)
# mid_sn1's coordinate: (11.38888888888889, 0.0)
# mid10_sn1's coordinate: (31.39176588294147, 100.64710355177588)
# mid12_sn1's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (31.96400199205263, 122.39207569799999)
# brch1's coordinate: (7.3706274, 0.0)

# %%
N23_25R.add_relation('mid12_sn1', 'mid10_sn1')
N23_25R.add_relation('mid10_sn1', 'mid_sn1')
N23_25R.add_relation('mid_sn1', 'tip_sn1')
N23_25R.add_relation('mid_sn1', 'tip_sn2')



lines = N23_25R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_25R)

# %% [markdown]
# # 23-25L Morphology

# %%
code = code_list[13]
N23_25L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 9 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (14.76, -18.45)
# mid_sn1's coordinate: (-1.968, 0.0)
# mid_sn2's coordinate: (3.3455999999999997, 0.0)
# mid10_sn1's coordinate: (32.17896588294147, 100.64710355177588)
# mid12_sn1's coordinate: (34.030402001000496, 122.392076038019)
# tip_cp's coordinate: (30.99120059178947, 85.42562248799999)
# brch1's coordinate: (28.37854278, 77.8123584)
# brchA2's coordinate: (15.925728564000002, 31.12494336)
# sp's coordinate: (0.0, 23.343707520000002)

# %%
N23_25L.add_relation('mid12_sn1', 'mid10_sn1')
N23_25L.add_relation('mid10_sn1', 'tip_cp')
N23_25L.add_relation('tip_cp', 'brch1')
N23_25L.add_relation('brch1', 'sp')
N23_25L.add_relation('brch1', 'brchA2')
N23_25L.add_relation('brchA2', 'mid_sn1')
N23_25L.add_relation('brchA2', 'mid_sn2')
N23_25L.add_relation('mid_sn2', 'tip_sn1')

lines = N23_25L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_25L)

# %% [markdown]
# # 24-10R Morphology

# %%
code = code_list[14]
N24_10R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 14 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-15.234736842105258, -18.45)
# tip_sn2's coordinate: (-12.42947368421052, -18.45)
# tip_sn3's coordinate: (-0.3452631578947365, -18.45)
# tip_sn4's coordinate: (3.8626315789473686, -18.45)
# mid_sn1's coordinate: (-4.423684210526315, 0.0)
# mid_sn2's coordinate: (-0.7552631578947367, 0.0)
# mid_sn3's coordinate: (5.394736842105263, 0.0)
# mid10_sn1's coordinate: (15.639134303994103, 100.64710355177588)
# mid10_sn2's coordinate: (28.370713251362524, 100.64710355177588)
# mid12_sn1's coordinate: (21.714002001000498, 122.392076038019)
# mid12_sn2's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (33.59842105263158, 184.5)
# brchA2's coordinate: (4.8875630796000005, 6.313396643999999)
# brchP2's coordinate: (-3.25796293296, 8.44835751558)

# %%
N24_10R.add_relation('mid12_sn1', 'mid10_sn1')
N24_10R.add_relation('mid10_sn1', 'brchP2')
N24_10R.add_relation('brchP2', 'mid_sn2')
N24_10R.add_relation('brchP2', 'mid_sn1')
N24_10R.add_relation('mid_sn1', 'tip_sn1')
N24_10R.add_relation('mid_sn2', 'tip_sn2')

N24_10R.add_relation('mid12_sn2', 'mid10_sn2')
N24_10R.add_relation('mid10_sn2', 'brchA2')
N24_10R.add_relation('brchA2', 'mid_sn3')
N24_10R.add_relation('mid_sn3', 'tip_sn4')
N24_10R.add_relation('mid_sn3', 'tip_sn3')


lines = N24_10R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N24_10R)

# %% [markdown]
# # 24-10L Morphology

# %%
code = code_list[15]
N24_10L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 9 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-4.880322580645162, -18.45)
# tip_sn2's coordinate: (2.8567741935483895, -18.45)
# mid_sn1's coordinate: (-3.868548387096774, 0.0)
# mid_sn2's coordinate: (1.9838709677419353, 0.0)
# mid10_sn1's coordinate: (18.89337878616728, 100.64710355177588)
# mid10_sn2's coordinate: (23.654669108747925, 100.64710355177588)
# mid12_sn1's coordinate: (23.63174393648437, 122.392076038019)
# mid12_sn2's coordinate: (27.401098775194047, 122.392076038019)
# tip_cp's coordinate: (33.59842105263158, 184.5)

# %%
N24_10L.add_relation('mid12_sn1', 'mid10_sn1')
N24_10L.add_relation('mid10_sn1', 'mid_sn1')
N24_10L.add_relation('mid_sn1', 'tip_sn1')

N24_10L.add_relation('mid12_sn2', 'mid10_sn2')
N24_10L.add_relation('mid10_sn2', 'mid_sn2')
N24_10L.add_relation('mid_sn2', 'tip_sn2')



lines = N24_10L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N24_10L)

# %% [markdown]
# # 23-49R Morphology

# %%
code = code_list[16]
N23_49R = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 7 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-4.769521276595741, -18.45)
# mid_sn1's coordinate: (-0.0, 0.0)
# mid10_sn1's coordinate: (27.662510563792534, 100.64710355177588)
# mid12_sn1's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (34.56947368421053, 221.4)
# brch1's coordinate: (31.23165908988, 190.57586794920002)
# sp's coordinate: (9.72558486864, 93.908150208)

# %%
N23_49R.add_relation('tip_cp', 'brch1')
N23_49R.add_relation('brch1', 'sp')
N23_49R.add_relation('brch1', 'mid12_sn1')
N23_49R.add_relation('mid12_sn1', 'mid10_sn1')
N23_49R.add_relation('mid10_sn1', 'mid_sn1')
N23_49R.add_relation('mid_sn1', 'tip_sn1')



lines = N23_49R.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_49R)

# %% [markdown]
# # 23-49L Morphology

# %%
code = code_list[17]
N23_49L = Nerve(code, raw_data=raw_dict[code], helper_data=helper_dict[code], bone=a)
# Out:
# Total 14 nodes have been located. Please refer to the below and relate each nodes.
# tip_sn1's coordinate: (-9.616943005181346, -18.45)
# tip_sn2's coordinate: (-4.932746113989635, -18.45)
# mid_sn1's coordinate: (-0.0, 0.0)
# mid_sn2's coordinate: (10.32435233160622, 0.0)
# mid_sn3's coordinate: (20.266321243523315, 0.0)
# mid_sn4's coordinate: (25.42849740932642, 0.0)
# mid10_sn1's coordinate: (21.545392825946653, 100.64710355177588)
# mid10_sn2's coordinate: (29.288657074651315, 100.64710355177588)
# mid12_sn1's coordinate: (29.191722208254383, 122.392076038019)
# mid12_sn2's coordinate: (31.964002001000498, 122.392076038019)
# tip_cp's coordinate: (34.56947368421053, 221.4)
# brchA2's coordinate: (18.454428354239997, 77.65419643919999)
# brchP2's coordinate: (24.260084334, 56.8543102704)
# sp's coordinate: (7.38, -11.07)

# %%
N23_49L.add_relation('mid12_sn2', 'mid10_sn2')
N23_49L.add_relation('mid10_sn2', 'brchP2')
N23_49L.add_relation('brchP2', 'mid_sn4')
N23_49L.add_relation('brchP2', 'mid_sn3')

N23_49L.add_relation('mid12_sn1', 'mid10_sn1')
N23_49L.add_relation('mid10_sn1', 'brchA2')
N23_49L.add_relation('brchA2', 'mid_sn2')
N23_49L.add_relation('brchA2', 'mid_sn1')

N23_49L.add_relation('mid_sn2', 'tip_sn2')
N23_49L.add_relation('mid_sn1', 'tip_sn1')




lines = N23_49L.get_branch_lines()
for line in lines:
    plt.plot(line[:,0], line[:,1], color='red')
    plt.plot(a.x, a.y)
plt.show()

Nerve_list.append(N23_49L)

# %%
print(len(Nerve_list))
# Out:
# 18

# %%
for nerve in Nerve_list:
    export_file_name = "./branches/" + nerve.get_name() + "_branches.npz"
    print(export_file_name)
    nerve.save_branch(export_file_name)
# Out:
# ./branches/23-21R_branches.npz
# ./branches/23-21L_branches.npz
# ./branches/23-27R_branches.npz
# ./branches/23-27L_branches.npz
# ./branches/23-34R_branches.npz
# ./branches/23-34L_branches.npz
# ./branches/22-20R_branches.npz
# ./branches/22-20L_branches.npz
# ./branches/23-6R_branches.npz
# ./branches/23-6L_branches.npz
# ./branches/23-24R_branches.npz
# ./branches/23-24L_branches.npz
# ./branches/23-25R_branches.npz
# ./branches/23-25L_branches.npz
# ./branches/24-10R_branches.npz
# ./branches/24-10L_branches.npz
# ./branches/23-49R_branches.npz
# ./branches/23-49L_branches.npz
